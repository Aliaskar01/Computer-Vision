# %% [markdown]
# # Track Boundary Detection — Strip Pipeline
#
# **Pipeline**: Resize → Strip (30/20/50) → Stretch middle → Baseline evaluation → Fine-tune → Analysis
#
# | Step | Operation | Detail |
# |------|-----------|--------|
# | 1 | **Resize** | 1280×720 → 256×128 (model input) |
# | 2 | **Strip 30/20/50** | Top 30% sky removed, **middle 20% kept**, bottom 50% car/chassis removed |
# | 3 | **Stretch** | Middle strip (144px tall) → full 128×256 resolution |
# | 4 | **Baseline** | Load `unet_road_curb_best.keras` (7.8M params), evaluate on strip data |
# | 5 | **Fine-tune** | Retrain on strip-space images, compare with baseline |
# | 6 | **Analyze** | Boundary extraction, error maps, quality buckets |
#
# **Baseline model**: `models/unet_road_curb_best.keras` (128×256 input, trained on full-frame data)

# %% [markdown]
# ## 0. Setup & Configuration

# %%
import os, gc, time
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import directed_hausdorff

np.random.seed(42)
tf.random.set_seed(42)

# GPU setup
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
tf.keras.mixed_precision.set_global_policy('mixed_float16')

# ── Paths ──
CAMERAS        = ['camera_fl', 'camera_fr']
IMG_DIR        = "dataset/images"           # 1280×720 originals
STRIP_IMG_DIR  = "dataset/images_strip"     # stripped+stretched images

# ── Model config ──
IMG_H, IMG_W = 128, 256                     # model input resolution
BATCH_SIZE   = 8
BASELINE_PATH = "models/unet_road_curb_best.keras"
FINETUNE_PATH = "models/unet_strip_finetuned.keras"

# ── Strip config: 50% top / 20% middle / 30% bottom ──
STRIP_TOP = 0.50   # remove top 50%  (sky, horizon)
STRIP_BOT = 0.30   # remove bottom 30% (car nose, chassis)
STRIP_MID = 1.0 - STRIP_TOP - STRIP_BOT  # keep middle 20%

# Pixel rows on 720px image
H_ORIG, W_ORIG = 720, 1280
Y_START = int(H_ORIG * STRIP_TOP)         # row 360
Y_END   = int(H_ORIG * (1 - STRIP_BOT))   # row 504
STRIP_H = Y_END - Y_START                  # 144 px

print(f"TF {tf.__version__} | GPU: {len(gpus)}")
print(f"Strip: top {STRIP_TOP*100:.0f}% / mid {STRIP_MID*100:.0f}% / bot {STRIP_BOT*100:.0f}%")
print(f"  → rows [{Y_START}:{Y_END}] = {STRIP_H}px of {H_ORIG}px")
print(f"  → stretched to {IMG_W}×{IMG_H}")
print(f"Baseline model: {BASELINE_PATH}")
# Out:
# TF 2.21.0 | GPU: 1
# Strip: top 50% / mid 20% / bot 30%
#   → rows [360:503] = 143px of 720px
#   → stretched to 256×128
# Baseline model: models/unet_road_curb_best.keras

# %%
# Show 5 sample preprocessed images with classic CV stages:
# grayscale -> normalize [0,1] -> gaussian blur -> laplacian edges
sample_paths = []
for cam_id in CAMERAS:
    cam_dir = os.path.join(STRIP_IMG_DIR, cam_id)
    if not os.path.isdir(cam_dir):
        continue
    files = sorted([f for f in os.listdir(cam_dir) if f.endswith('.jpg')])
    sample_paths.extend([(cam_id, os.path.join(cam_dir, f), f) for f in files])

if len(sample_paths) == 0:
    raise FileNotFoundError(f"No preprocessed images found in: {STRIP_IMG_DIR}")

n_show = min(5, len(sample_paths))
idxs = np.linspace(0, len(sample_paths) - 1, n_show, dtype=int)
chosen = [sample_paths[i] for i in idxs]

fig, axes = plt.subplots(n_show, 4, figsize=(16, 3.2 * n_show))
if n_show == 1:
    axes = np.expand_dims(axes, axis=0)

col_titles = ["Grayscale", "Normalized [0,1]", "Gaussian Blur", "Laplacian Edges"]
for col, t in enumerate(col_titles):
    axes[0, col].set_title(t, fontweight='bold')

for row, (cam_id, img_path, fname) in enumerate(chosen):
    img_bgr = cv2.imread(img_path)
    gray_u8 = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    gray_norm = gray_u8.astype(np.float32) / 255.0
    blur = cv2.GaussianBlur(gray_norm, (5, 5), 0)
    lap = cv2.Laplacian(blur, cv2.CV_32F, ksize=3)
    lap_vis = cv2.normalize(np.abs(lap), None, 0.0, 1.0, cv2.NORM_MINMAX)

    axes[row, 0].imshow(gray_u8, cmap='gray', vmin=0, vmax=255)
    axes[row, 1].imshow(gray_norm, cmap='gray', vmin=0.0, vmax=1.0)
    axes[row, 2].imshow(blur, cmap='gray', vmin=0.0, vmax=1.0)
    axes[row, 3].imshow(lap_vis, cmap='gray', vmin=0.0, vmax=1.0)

    axes[row, 0].set_ylabel(f"{cam_id}\n{fname}", fontsize=8)
    for col in range(4):
        axes[row, col].axis('off')

plt.suptitle("Sample of 5 Images — Gray, Normalize, Blur, Laplacian", fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1. Baseline Model — Road Edge Detection
#
# Train a lightweight segmentation baseline on strip images using **auto-generated edge pseudo-labels**:
# - Pseudo-labels: grayscale → Gaussian blur → Canny edges + lower-road ROI
# - Model: small U-Net style encoder-decoder
# - Loss: binary cross-entropy
# - Metric: IoU + Dice
#
# This provides a fast baseline before moving to stronger supervised models.

# %%
# Build training data from strip images + edge pseudo-labels
EDGE_MODEL_PATH = "models/road_edge_baseline.keras"
MAX_SAMPLES = 2000
VAL_SPLIT = 0.20

def build_edge_pseudolabel(img_bgr):
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)
    edges = cv2.Canny(blur, 60, 160)

    h, w = edges.shape
    roi = np.zeros((h, w), dtype=np.uint8)
    roi[int(h * 0.35):, :] = 255
    edges = cv2.bitwise_and(edges, roi)

    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    edges = cv2.dilate(edges, kernel, iterations=1)
    return (edges > 0).astype(np.float32)

# Collect strip image paths
img_paths = []
for cam_id in CAMERAS:
    cam_dir = os.path.join(STRIP_IMG_DIR, cam_id)
    if not os.path.isdir(cam_dir):
        continue
    files = sorted([f for f in os.listdir(cam_dir) if f.endswith('.jpg')])
    img_paths.extend([os.path.join(cam_dir, f) for f in files])

if len(img_paths) == 0:
    raise FileNotFoundError(f"No strip images found in: {STRIP_IMG_DIR}")

if len(img_paths) > MAX_SAMPLES:
    idxs = np.linspace(0, len(img_paths) - 1, MAX_SAMPLES, dtype=int)
    img_paths = [img_paths[i] for i in idxs]

n = len(img_paths)
X = np.zeros((n, IMG_H, IMG_W, 3), dtype=np.float32)
Y = np.zeros((n, IMG_H, IMG_W, 1), dtype=np.float32)

for i, p in enumerate(img_paths):
    img_bgr = cv2.imread(p)
    if img_bgr is None:
        continue
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    X[i] = img_rgb.astype(np.float32) / 255.0
    Y[i, :, :, 0] = build_edge_pseudolabel(img_bgr)

X_train, X_val, Y_train, Y_val = train_test_split(
    X, Y, test_size=VAL_SPLIT, random_state=42
 )

print(f"Loaded {n} samples | Train: {len(X_train)} | Val: {len(X_val)}")
print(f"Edge coverage (train): {Y_train.mean() * 100:.2f}%")
print(f"Edge coverage (val):   {Y_val.mean() * 100:.2f}%")
# Out:
# Loaded 2000 samples | Train: 1600 | Val: 400
# Edge coverage (train): 3.40%
# Edge coverage (val):   3.35%

# %%
# Baseline road-edge model (small U-Net style)
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1])
    y_pred_f = tf.reshape(tf.cast(y_pred > 0.5, tf.float32), [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def build_edge_baseline(input_shape=(IMG_H, IMG_W, 3)):
    inputs = layers.Input(shape=input_shape)

    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(16, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPool2D()(c1)

    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(32, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPool2D()(c2)

    b = layers.Conv2D(64, 3, activation='relu', padding='same')(p2)
    b = layers.Conv2D(64, 3, activation='relu', padding='same')(b)

    u1 = layers.UpSampling2D()(b)
    u1 = layers.Concatenate()([u1, c2])
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(u1)
    c3 = layers.Conv2D(32, 3, activation='relu', padding='same')(c3)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.Concatenate()([u2, c1])
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(u2)
    c4 = layers.Conv2D(16, 3, activation='relu', padding='same')(c4)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)
    return Model(inputs, outputs, name='road_edge_baseline')

tf.keras.backend.clear_session()
edge_model = build_edge_baseline()
edge_model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss='binary_crossentropy',
    metrics=[dice_coefficient, iou_metric],
)
edge_model.summary()

callbacks = [
    ModelCheckpoint(EDGE_MODEL_PATH, monitor='val_iou_metric', mode='max', save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_iou_metric', mode='max', patience=4, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1),
]

history = edge_model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=12,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1,
 )

edge_model = tf.keras.models.load_model(
    EDGE_MODEL_PATH,
    custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric},
)
print(f"Saved baseline model: {EDGE_MODEL_PATH}")
# Out:
# I0000 00:00:1773166798.081246    4679 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6631 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "road_edge_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 256,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 128,   │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 128,   │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 128,   │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 64,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 64,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 128,   │          0 │ conv2d_5[0][0]    │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 128,   │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 96)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 128,   │     27,680 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 128,   │      9,248 │ conv2d_6[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 256,  │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 256,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 256,  │      6,928 │ concatenate_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 256,  │      2,320 │ conv2d_8[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 256,  │         17 │ conv2d_9[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 118,273 (462.00 KB)
#  Trainable params: 118,273 (462.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/12
# I0000 00:00:1773166802.244973   10864 service.cc:153] XLA service 0x7a7b70006e20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1773166802.244993   10864 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2070 with Max-Q Design, Compute Capability 7.5 (Driver: 13.0.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.19.0)
# I0000 00:00:1773166802.326752   10864 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1773166802.864965   10864 cuda_dnn.cc:461] Loaded cuDNN version 91900
# E0000 00:00:1773166804.467751   10864 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1773166804.981641   10864 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1773166805.433675   10864 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1773166805.867781   10864 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1773166806.335846   10864 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   5/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - dice_coefficient: 0.0718 - iou_metric: 0.0211 - loss: 0.6885
# I0000 00:00:1773166810.623416   10864 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dice_coefficient: 0.0820 - iou_metric: 0.0064 - loss: 0.2482
# Epoch 1: val_iou_metric improved from None to 0.17193, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 18s 35ms/step - dice_coefficient: 0.1526 - iou_metric: 0.0420 - loss: 0.1461 - val_dice_coefficient: 0.2969 - val_iou_metric: 0.1719 - val_loss: 0.0773 - learning_rate: 0.0010
# Epoch 2/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dice_coefficient: 0.3465 - iou_metric: 0.2361 - loss: 0.0753
# Epoch 2: val_iou_metric improved from 0.17193 to 0.33252, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.3857 - iou_metric: 0.2903 - loss: 0.0689 - val_dice_coefficient: 0.3937 - val_iou_metric: 0.3325 - val_loss: 0.0634 - learning_rate: 0.0010
# Epoch 3/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dice_coefficient: 0.4352 - iou_metric: 0.3531 - loss: 0.0628
# Epoch 3: val_iou_metric improved from 0.33252 to 0.36981, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.4587 - iou_metric: 0.3787 - loss: 0.0590 - val_dice_coefficient: 0.4787 - val_iou_metric: 0.3698 - val_loss: 0.0546 - learning_rate: 0.0010
# Epoch 4/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dice_coefficient: 0.4725 - iou_metric: 0.3897 - loss: 0.0586
# Epoch 4: val_iou_metric improved from 0.36981 to 0.42932, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.4903 - iou_metric: 0.4101 - loss: 0.0555 - val_dice_coefficient: 0.5082 - val_iou_metric: 0.4293 - val_loss: 0.0517 - learning_rate: 0.0010
# Epoch 5/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.5127 - iou_metric: 0.4299 - loss: 0.0536
# Epoch 5: val_iou_metric improved from 0.42932 to 0.44003, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.5216 - iou_metric: 0.4409 - loss: 0.0518 - val_dice_coefficient: 0.5251 - val_iou_metric: 0.4400 - val_loss: 0.0503 - learning_rate: 0.0010
# Epoch 6/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.5320 - iou_metric: 0.4516 - loss: 0.0513
# Epoch 6: val_iou_metric improved from 0.44003 to 0.45620, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.5410 - iou_metric: 0.4618 - loss: 0.0496 - val_dice_coefficient: 0.5423 - val_iou_metric: 0.4562 - val_loss: 0.0486 - learning_rate: 0.0010
# Epoch 7/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.5500 - iou_metric: 0.4699 - loss: 0.0494
# Epoch 7: val_iou_metric improved from 0.45620 to 0.48316, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.5592 - iou_metric: 0.4800 - loss: 0.0477 - val_dice_coefficient: 0.5530 - val_iou_metric: 0.4832 - val_loss: 0.0472 - learning_rate: 0.0010
# Epoch 8/12
# 198/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.5671 - iou_metric: 0.4873 - loss: 0.0475
# Epoch 8: val_iou_metric improved from 0.48316 to 0.52389, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.5759 - iou_metric: 0.4981 - loss: 0.0459 - val_dice_coefficient: 0.5864 - val_iou_metric: 0.5239 - val_loss: 0.0451 - learning_rate: 0.0010
# Epoch 9/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.5849 - iou_metric: 0.5063 - loss: 0.0455
# Epoch 9: val_iou_metric did not improve from 0.52389
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.5901 - iou_metric: 0.5134 - loss: 0.0443 - val_dice_coefficient: 0.5913 - val_iou_metric: 0.5182 - val_loss: 0.0445 - learning_rate: 0.0010
# Epoch 10/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.5967 - iou_metric: 0.5208 - loss: 0.0443
# Epoch 10: val_iou_metric did not improve from 0.52389
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.6023 - iou_metric: 0.5274 - loss: 0.0431 - val_dice_coefficient: 0.5868 - val_iou_metric: 0.5019 - val_loss: 0.0441 - learning_rate: 0.0010
# Epoch 11/12
# 198/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.6039 - iou_metric: 0.5289 - loss: 0.0435
# Epoch 11: val_iou_metric did not improve from 0.52389
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.6118 - iou_metric: 0.5382 - loss: 0.0422 - val_dice_coefficient: 0.6019 - val_iou_metric: 0.5225 - val_loss: 0.0428 - learning_rate: 0.0010
# Epoch 12/12
# 198/200 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dice_coefficient: 0.6164 - iou_metric: 0.5433 - loss: 0.0421
# Epoch 12: val_iou_metric improved from 0.52389 to 0.52593, saving model to models/road_edge_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - dice_coefficient: 0.6220 - iou_metric: 0.5512 - loss: 0.0412 - val_dice_coefficient: 0.6073 - val_iou_metric: 0.5259 - val_loss: 0.0425 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 12.
# Saved baseline model: models/road_edge_baseline.keras

# %%
# Baseline evaluation + qualitative results
pred_val = edge_model.predict(X_val, batch_size=BATCH_SIZE, verbose=0)
pred_bin = (pred_val > 0.5).astype(np.float32)

intersection = np.sum(Y_val * pred_bin, axis=(1, 2, 3))
union = np.sum(Y_val, axis=(1, 2, 3)) + np.sum(pred_bin, axis=(1, 2, 3)) - intersection
iou_scores = (intersection + 1e-6) / (union + 1e-6)
print(f"Validation IoU: {iou_scores.mean():.4f} ± {iou_scores.std():.4f}")

n_show = min(5, len(X_val))
idxs = np.linspace(0, len(X_val) - 1, n_show, dtype=int)
fig, axes = plt.subplots(n_show, 4, figsize=(14, 3 * n_show))
if n_show == 1:
    axes = np.expand_dims(axes, axis=0)

titles = ["Input", "Pseudo GT Edge", "Pred Prob", "Pred Edge (>0.5)"]
for c, t in enumerate(titles):
    axes[0, c].set_title(t, fontweight='bold')

for r, idx in enumerate(idxs):
    axes[r, 0].imshow(X_val[idx])
    axes[r, 1].imshow(Y_val[idx, :, :, 0], cmap='gray', vmin=0, vmax=1)
    axes[r, 2].imshow(pred_val[idx, :, :, 0], cmap='inferno', vmin=0, vmax=1)
    axes[r, 3].imshow(pred_bin[idx, :, :, 0], cmap='gray', vmin=0, vmax=1)
    axes[r, 0].set_ylabel(f"IoU={iou_scores[idx]:.2f}", rotation=0, labelpad=35, fontsize=9, va='center')
    for c in range(4):
        axes[r, c].axis('off')

plt.suptitle("Road Edge Baseline — Validation Samples", fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Validation IoU: 0.4776 ± 0.2144

# %% [markdown]
# ## 2. Next Step — Segment Runnable Road
#
# Convert edge predictions into **drivable road-area pseudo-labels**, then train a road-surface segmentation baseline.
#
# Approach:
# - Predict edge probability maps with the edge baseline
# - Convert edges to barriers and flood-fill from bottom-center seed
# - Train a second lightweight U-Net on road-area masks

# %%
# Build runnable-road pseudo-labels from edge model predictions
ROAD_MODEL_PATH = "models/runnable_road_baseline.keras"
ROAD_EDGE_THRESH = 0.35
ROAD_MAX_SAMPLES = 2000

def edge_to_runnable_road(edge_prob, edge_thresh=ROAD_EDGE_THRESH):
    h, w = edge_prob.shape
    edge_bin = (edge_prob > edge_thresh).astype(np.uint8) * 255
    edge_bin = cv2.dilate(edge_bin, cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3)), iterations=1)

    # Keep only lower-road ROI
    roi = np.zeros((h, w), dtype=np.uint8)
    roi[int(h * 0.35):, :] = 255
    barrier = cv2.bitwise_and(edge_bin, roi)

    # Flood-fill free-space from bottom-center
    free = cv2.bitwise_not(barrier)
    ff = free.copy()
    ff_mask = np.zeros((h + 2, w + 2), dtype=np.uint8)
    seed = (w // 2, h - 2)
    cv2.floodFill(ff, ff_mask, seedPoint=seed, newVal=128)
    road = (ff == 128).astype(np.uint8)

    # Clean mask
    road = cv2.morphologyEx(road, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3)), iterations=1)
    road = cv2.morphologyEx(road, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)), iterations=1)
    return road.astype(np.float32)

# Use existing X if available; otherwise rebuild quickly from strip images
if 'X' not in globals() or X is None or len(X) == 0:
    img_paths = []
    for cam_id in CAMERAS:
        cam_dir = os.path.join(STRIP_IMG_DIR, cam_id)
        if not os.path.isdir(cam_dir):
            continue
        files = sorted([f for f in os.listdir(cam_dir) if f.endswith('.jpg')])
        img_paths.extend([os.path.join(cam_dir, f) for f in files])

    if len(img_paths) == 0:
        raise FileNotFoundError(f"No strip images found in: {STRIP_IMG_DIR}")

    if len(img_paths) > ROAD_MAX_SAMPLES:
        idxs = np.linspace(0, len(img_paths) - 1, ROAD_MAX_SAMPLES, dtype=int)
        img_paths = [img_paths[i] for i in idxs]

    X = np.zeros((len(img_paths), IMG_H, IMG_W, 3), dtype=np.float32)
    for i, p in enumerate(img_paths):
        img_bgr = cv2.imread(p)
        img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
        X[i] = img_rgb.astype(np.float32) / 255.0

# Ensure edge model is available
if 'edge_model' not in globals() or edge_model is None:
    edge_model = tf.keras.models.load_model(
        EDGE_MODEL_PATH,
        custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric},
    )

edge_prob_all = edge_model.predict(X, batch_size=BATCH_SIZE, verbose=0)
Y_road = np.zeros((len(X), IMG_H, IMG_W, 1), dtype=np.float32)
for i in range(len(X)):
    Y_road[i, :, :, 0] = edge_to_runnable_road(edge_prob_all[i, :, :, 0])

Xr_train, Xr_val, Yr_train, Yr_val = train_test_split(
    X, Y_road, test_size=0.20, random_state=42
 )

print(f"Road pseudo-labels: total {len(X)} | train {len(Xr_train)} | val {len(Xr_val)}")
print(f"Road coverage (train): {Yr_train.mean() * 100:.2f}%")
print(f"Road coverage (val):   {Yr_val.mean() * 100:.2f}%")
# Out:
# Road pseudo-labels: total 2000 | train 1600 | val 400
# Road coverage (train): 94.31%
# Road coverage (val):   94.56%

# %%
# Train runnable-road segmentation baseline
def build_road_baseline(input_shape=(IMG_H, IMG_W, 3)):
    inputs = layers.Input(shape=input_shape)

    c1 = layers.Conv2D(24, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(24, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPool2D()(c1)

    c2 = layers.Conv2D(48, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(48, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPool2D()(c2)

    b = layers.Conv2D(96, 3, activation='relu', padding='same')(p2)
    b = layers.Conv2D(96, 3, activation='relu', padding='same')(b)

    u1 = layers.UpSampling2D()(b)
    u1 = layers.Concatenate()([u1, c2])
    c3 = layers.Conv2D(48, 3, activation='relu', padding='same')(u1)
    c3 = layers.Conv2D(48, 3, activation='relu', padding='same')(c3)

    u2 = layers.UpSampling2D()(c3)
    u2 = layers.Concatenate()([u2, c1])
    c4 = layers.Conv2D(24, 3, activation='relu', padding='same')(u2)
    c4 = layers.Conv2D(24, 3, activation='relu', padding='same')(c4)

    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c4)
    return Model(inputs, outputs, name='runnable_road_baseline')

tf.keras.backend.clear_session()
road_model = build_road_baseline()
road_model.compile(
    optimizer=keras.optimizers.Adam(8e-4),
    loss='binary_crossentropy',
    metrics=[dice_coefficient, iou_metric],
)
road_model.summary()

road_callbacks = [
    ModelCheckpoint(ROAD_MODEL_PATH, monitor='val_iou_metric', mode='max', save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_iou_metric', mode='max', patience=4, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1),
]

road_history = road_model.fit(
    Xr_train, Yr_train,
    validation_data=(Xr_val, Yr_val),
    epochs=12,
    batch_size=BATCH_SIZE,
    callbacks=road_callbacks,
    verbose=1,
 )

road_model = tf.keras.models.load_model(
    ROAD_MODEL_PATH,
    custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric},
)
print(f"Saved runnable-road model: {ROAD_MODEL_PATH}")
# Out:
# Model: "runnable_road_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 256,  │        672 │ input_layer[0][0] │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 256,  │      5,208 │ conv2d[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 128,   │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 128,   │     10,416 │ max_pooling2d[0]… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 128,   │     20,784 │ conv2d_2[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 64,    │     41,568 │ max_pooling2d_1[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 64,    │     83,040 │ conv2d_4[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 128,   │          0 │ conv2d_5[0][0]    │
# │ (UpSampling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 128,   │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 144)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 128,   │     62,256 │ concatenate[0][0] │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 128,   │     20,784 │ conv2d_6[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 256,  │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 256,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 72)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 256,  │     15,576 │ concatenate_1[0]… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 256,  │      5,208 │ conv2d_8[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 256,  │         25 │ conv2d_9[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 265,537 (1.01 MB)
#  Trainable params: 265,537 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/12
# E0000 00:00:1773167066.128910   10863 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1773167067.159143   10863 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1773167068.220027   10863 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# W0000 00:00:1773167068.672556   10863 bfc_allocator.cc:383] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# E0000 00:00:1773167069.377072   10863 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1773167070.271969   10863 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - dice_coefficient: 0.8982 - iou_metric: 0.9126 - loss: 0.3065
# W0000 00:00:1773167092.441959   10867 bfc_allocator.cc:502] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.97GiB (rounded to 4261137920)requested by op
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# I0000 00:00:1773167092.449377   10867 bfc_allocator.cc:1049] BFCAllocator dump for GPU_0_bfc
# I0000 00:00:1773167092.449391   10867 bfc_allocator.cc:1056] Bin (256): 	Total Chunks: 188, Chunks in use: 187. 47.0KiB allocated for chunks. 46.8KiB in use in bin. 11.9KiB client-requested in use in bin.
# I0000 00:00:1773167092.449405   10867 bfc_allocator.cc:1056] Bin (512): 	Total Chunks: 6, Chunks in use: 6. 3.0KiB allocated for chunks. 3.0KiB in use in bin. 2.2KiB client-requested in use in bin.
# I0000 00:00:1773167092.449407   10867 bfc_allocator.cc:1056] Bin (1024): 	Total Chunks: 9, Chunks in use: 7. 14.2KiB allocated for chunks. 11.8KiB in use in bin. 11.1KiB client-requested in use in bin.
# I0000 00:00:1773167092.449409   10867 bfc_allocator.cc:1056] Bin (2048): 	Total Chunks: 3, Chunks in use: 3. 8.2KiB allocated for chunks. 8.2KiB in use in bin. 7.6KiB client-requested in use in bin.
# I0000 00:00:1773167092.449411   10867 bfc_allocator.cc:1056] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1773167092.449413   10867 bfc_allocator.cc:1056] Bin (8192): 	Total Chunks: 12, Chunks in use: 12. 119.0KiB allocated for chunks. 119.0KiB in use in bin. 108.0KiB client-requested in use in bin.
# I0000 00:00:1773167092.449415   10867 bfc_allocator.cc:1056] Bin (16384): 	Total Chunks: 17, Chunks in use: 16. 387.0KiB allocated for chunks. 360.8KiB in use in bin. 344.2KiB client-requested in use in bin.
# I0000 00:00:1773167092.449418   10867 bfc_allocator.cc:1056] Bin (32768): 	Total Chunks: 20, Chunks in use: 19. 822.0KiB allocated for chunks. 761.2KiB in use in bin. 722.2KiB client-requested in use in bin.
# I0000 00:00:1773167092.449420   10867 bfc_allocator.cc:1056] Bin (65536): 	Total Chunks: 17, Chunks in use: 16. 1.43MiB allocated for chunks. 1.35MiB in use in bin. 1.27MiB client-requested in use in bin.
# I0000 00:00:1773167092.449422   10867 bfc_allocator.cc:1056] Bin (131072): 	Total Chunks: 15, Chunks in use: 15. 2.55MiB allocated for chunks. 2.55MiB in use in bin. 2.35MiB client-requested in use in bin.
# I0000 00:00:1773167092.449424   10867 bfc_allocator.cc:1056] Bin (262144): 	Total Chunks: 3, Chunks in use: 3. 972.0KiB allocated for chunks. 972.0KiB in use in bin. 972.0KiB client-requested in use in bin.
# I0000 00:00:1773167092.449426   10867 bfc_allocator.cc:1056] Bin (524288): 	Total Chunks: 1, Chunks in use: 0. 648.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1773167092.449428   10867 bfc_allocator.cc:1056] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.00MiB allocated for chunks. 1.00MiB in use in bin. 1.00MiB client-requested in use in bin.
# I0000 00:00:1773167092.449430   10867 bfc_allocator.cc:1056] Bin (2097152): 	Total Chunks: 1, Chunks in use: 1. 3.28MiB allocated for chunks. 3.28MiB in use in bin. 3.00MiB client-requested in use in bin.
# I0000 00:00:1773167092.449432   10867 bfc_allocator.cc:1056] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1773167092.449434   10867 bfc_allocator.cc:1056] Bin (8388608): 	Total Chunks: 2, Chunks in use: 2. 24.00MiB allocated for chunks. 24.00MiB in use in bin. 24.00MiB client-requested in use in bin.
# I0000 00:00:1773167092.449436   10867 bfc_allocator.cc:1056] Bin (16777216): 	Total Chunks: 2, Chunks in use: 2. 32.24MiB allocated for chunks. 32.24MiB in use in bin. 32.24MiB client-requested in use in bin.
# I0000 00:00:1773167092.449437   10867 bfc_allocator.cc:1056] Bin (33554432): 	Total Chunks: 2, Chunks in use: 2. 102.00MiB allocated for chunks. 102.00MiB in use in bin. 102.00MiB client-requested in use in bin.
# I0000 00:00:1773167092.449440   10867 bfc_allocator.cc:1056] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# I0000 00:00:1773167092.449441   10867 bfc_allocator.cc:1056] Bin (134217728): 	Total Chunks: 2, Chunks in use: 2. 414.80MiB allocated for chunks. 414.80MiB in use in bin. 350.00MiB client-requested in use in bin.
# I0000 00:00:1773167092.449447   10867 bfc_allocator.cc:1056] Bin (268435456): 	Total Chunks: 2, Chunks in use: 1. 4.43GiB allocated for chunks. 600.00MiB in use in bin. 600.00MiB client-requested in use in bin.
# I0000 00:00:1773167092.449449   10867 bfc_allocator.cc:1072] Bin for 3.97GiB was 256.00MiB, Chunk State:
# I0000 00:00:1773167092.449451   10867 bfc_allocator.cc:1078]   Size: 3.84GiB | Requested Size: 48.28MiB | in_use: 0 | bin_num: 20, prev:   Size: 12.00MiB | Requested Size: 12.00MiB | in_use: 1 | bin_num: -1
# I0000 00:00:1773167092.449458   10867 bfc_allocator.cc:1085] Next region of size 4294967296
# I0000 00:00:1773167092.449462   10867 bfc_allocator.cc:1105] InUse at 7a7776000000 of size 52428800 next 252
# I0000 00:00:1773167092.449463   10867 bfc_allocator.cc:1105] InUse at 7a7779200000 of size 54525952 next 304
# I0000 00:00:1773167092.449465   10867 bfc_allocator.cc:1105] InUse at 7a777c600000 of size 17026048 next 259
# I0000 00:00:1773167092.449467   10867 bfc_allocator.cc:1105] InUse at 7a777d63cc00 of size 16777472 next 305
# I0000 00:00:1773167092.449469   10867 bfc_allocator.cc:1105] InUse at 7a777e63cd00 of size 12582912 next 253
# I0000 00:00:1773167092.449470   10867 bfc_allocator.cc:1105] InUse at 7a777f23cd00 of size 12582912 next 249
# I0000 00:00:1773167092.449473   10867 bfc_allocator.cc:1105] Free  at 7a777fe3cd00 of size 4129043200 next 18446744073709551615
# I0000 00:00:1773167092.449474   10867 bfc_allocator.cc:1085] Next region of size 1073741824
# I0000 00:00:1773167092.449476   10867 bfc_allocator.cc:1105] InUse at 7a7a9c000000 of size 629145600 next 241
# I0000 00:00:1773167092.449478   10867 bfc_allocator.cc:1105] InUse at 7a7ac1800000 of size 212860928 next 64
# I0000 00:00:1773167092.449481   10867 bfc_allocator.cc:1105] InUse at 7a7ace300000 of size 9216 next 78
# I0000 00:00:1773167092.449484   10867 bfc_allocator.cc:1105] InUse at 7a7ace302400 of size 256 next 79
# I0000 00:00:1773167092.449486   10867 bfc_allocator.cc:1105] InUse at 7a7ace302500 of size 256 next 80
# I0000 00:00:1773167092.449487   10867 bfc_allocator.cc:1105] InUse at 7a7ace302600 of size 18432 next 81
# I0000 00:00:1773167092.449488   10867 bfc_allocator.cc:1105] InUse at 7a7ace306e00 of size 18432 next 82
# I0000 00:00:1773167092.449489   10867 bfc_allocator.cc:1105] InUse at 7a7ace30b600 of size 256 next 83
# I0000 00:00:1773167092.449490   10867 bfc_allocator.cc:1105] InUse at 7a7ace30b700 of size 256 next 84
# I0000 00:00:1773167092.449491   10867 bfc_allocator.cc:1105] InUse at 7a7ace30b800 of size 36864 next 85
# I0000 00:00:1773167092.449492   10867 bfc_allocator.cc:1105] InUse at 7a7ace314800 of size 36864 next 86
# I0000 00:00:1773167092.449493   10867 bfc_allocator.cc:1105] InUse at 7a7ace31d800 of size 256 next 87
# I0000 00:00:1773167092.449494   10867 bfc_allocator.cc:1105] InUse at 7a7ace31d900 of size 256 next 88
# I0000 00:00:1773167092.449495   10867 bfc_allocator.cc:1105] InUse at 7a7ace31da00 of size 73728 next 89
# I0000 00:00:1773167092.449496   10867 bfc_allocator.cc:1105] InUse at 7a7ace32fa00 of size 73728 next 90
# I0000 00:00:1773167092.449497   10867 bfc_allocator.cc:1105] InUse at 7a7ace341a00 of size 256 next 91
# I0000 00:00:1773167092.449498   10867 bfc_allocator.cc:1105] InUse at 7a7ace341b00 of size 256 next 92
# I0000 00:00:1773167092.449499   10867 bfc_allocator.cc:1105] InUse at 7a7ace341c00 of size 147456 next 93
# I0000 00:00:1773167092.449500   10867 bfc_allocator.cc:1105] InUse at 7a7ace365c00 of size 147456 next 94
# I0000 00:00:1773167092.449501   10867 bfc_allocator.cc:1105] InUse at 7a7ace389c00 of size 256 next 95
# I0000 00:00:1773167092.449502   10867 bfc_allocator.cc:1105] InUse at 7a7ace389d00 of size 256 next 96
# I0000 00:00:1773167092.449503   10867 bfc_allocator.cc:1105] InUse at 7a7ace389e00 of size 110592 next 97
# I0000 00:00:1773167092.449504   10867 bfc_allocator.cc:1105] InUse at 7a7ace3a4e00 of size 110592 next 98
# I0000 00:00:1773167092.449507   10867 bfc_allocator.cc:1105] InUse at 7a7ace3bfe00 of size 256 next 99
# I0000 00:00:1773167092.449508   10867 bfc_allocator.cc:1105] InUse at 7a7ace3bff00 of size 256 next 100
# I0000 00:00:1773167092.449509   10867 bfc_allocator.cc:1105] InUse at 7a7ace3c0000 of size 36864 next 101
# I0000 00:00:1773167092.449509   10867 bfc_allocator.cc:1105] InUse at 7a7ace3c9000 of size 36864 next 102
# I0000 00:00:1773167092.449510   10867 bfc_allocator.cc:1105] InUse at 7a7ace3d2000 of size 256 next 103
# I0000 00:00:1773167092.449511   10867 bfc_allocator.cc:1105] InUse at 7a7ace3d2100 of size 256 next 104
# I0000 00:00:1773167092.449512   10867 bfc_allocator.cc:1105] InUse at 7a7ace3d2200 of size 27648 next 105
# I0000 00:00:1773167092.449513   10867 bfc_allocator.cc:1105] InUse at 7a7ace3d8e00 of size 27648 next 106
# I0000 00:00:1773167092.449514   10867 bfc_allocator.cc:1105] InUse at 7a7ace3dfa00 of size 256 next 107
# I0000 00:00:1773167092.449515   10867 bfc_allocator.cc:1105] InUse at 7a7ace3dfb00 of size 256 next 108
# I0000 00:00:1773167092.449516   10867 bfc_allocator.cc:1105] InUse at 7a7ace3dfc00 of size 9216 next 109
# I0000 00:00:1773167092.449517   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e2000 of size 9216 next 110
# I0000 00:00:1773167092.449518   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4400 of size 256 next 111
# I0000 00:00:1773167092.449519   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4500 of size 256 next 112
# I0000 00:00:1773167092.449520   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4600 of size 256 next 113
# I0000 00:00:1773167092.449521   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4700 of size 256 next 114
# I0000 00:00:1773167092.449522   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4800 of size 256 next 115
# I0000 00:00:1773167092.449523   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4900 of size 256 next 116
# I0000 00:00:1773167092.449524   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4a00 of size 256 next 48
# I0000 00:00:1773167092.449525   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4b00 of size 256 next 118
# I0000 00:00:1773167092.449526   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4c00 of size 256 next 67
# I0000 00:00:1773167092.449526   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4d00 of size 256 next 120
# I0000 00:00:1773167092.449527   10867 bfc_allocator.cc:1105] InUse at 7a7ace3e4e00 of size 36864 next 30
# I0000 00:00:1773167092.449528   10867 bfc_allocator.cc:1105] InUse at 7a7ace3ede00 of size 73728 next 210
# I0000 00:00:1773167092.449529   10867 bfc_allocator.cc:1105] InUse at 7a7ace3ffe00 of size 147456 next 211
# I0000 00:00:1773167092.449530   10867 bfc_allocator.cc:1105] InUse at 7a7ace423e00 of size 41472 next 214
# I0000 00:00:1773167092.449531   10867 bfc_allocator.cc:1105] Free  at 7a7ace42e000 of size 62208 next 234
# I0000 00:00:1773167092.449533   10867 bfc_allocator.cc:1105] InUse at 7a7ace43d300 of size 103680 next 218
# I0000 00:00:1773167092.449534   10867 bfc_allocator.cc:1105] InUse at 7a7ace456800 of size 82944 next 217
# I0000 00:00:1773167092.449535   10867 bfc_allocator.cc:1105] InUse at 7a7ace46ac00 of size 82944 next 232
# I0000 00:00:1773167092.449536   10867 bfc_allocator.cc:1105] Free  at 7a7ace47f000 of size 82944 next 222
# I0000 00:00:1773167092.449537   10867 bfc_allocator.cc:1105] InUse at 7a7ace493400 of size 165888 next 221
# I0000 00:00:1773167092.449538   10867 bfc_allocator.cc:1105] Free  at 7a7ace4bbc00 of size 663552 next 228
# I0000 00:00:1773167092.449539   10867 bfc_allocator.cc:1105] InUse at 7a7ace55dc00 of size 331776 next 227
# I0000 00:00:1773167092.449540   10867 bfc_allocator.cc:1105] InUse at 7a7ace5aec00 of size 248832 next 230
# I0000 00:00:1773167092.449541   10867 bfc_allocator.cc:1105] InUse at 7a7ace5eb800 of size 1048576 next 306
# I0000 00:00:1773167092.449543   10867 bfc_allocator.cc:1105] InUse at 7a7ace6eb800 of size 3436032 next 251
# I0000 00:00:1773167092.449565   10867 bfc_allocator.cc:1105] InUse at 7a7acea32600 of size 20736 next 265
# I0000 00:00:1773167092.449567   10867 bfc_allocator.cc:1105] InUse at 7a7acea37700 of size 256 next 266
# I0000 00:00:1773167092.449568   10867 bfc_allocator.cc:1105] InUse at 7a7acea37800 of size 256 next 267
# I0000 00:00:1773167092.449568   10867 bfc_allocator.cc:1105] InUse at 7a7acea37900 of size 41472 next 268
# I0000 00:00:1773167092.449569   10867 bfc_allocator.cc:1105] InUse at 7a7acea41b00 of size 41472 next 269
# I0000 00:00:1773167092.449570   10867 bfc_allocator.cc:1105] InUse at 7a7acea4bd00 of size 256 next 270
# I0000 00:00:1773167092.449571   10867 bfc_allocator.cc:1105] InUse at 7a7acea4be00 of size 256 next 271
# I0000 00:00:1773167092.449572   10867 bfc_allocator.cc:1105] InUse at 7a7acea4bf00 of size 82944 next 272
# I0000 00:00:1773167092.449573   10867 bfc_allocator.cc:1105] InUse at 7a7acea60300 of size 82944 next 273
# I0000 00:00:1773167092.449574   10867 bfc_allocator.cc:1105] InUse at 7a7acea74700 of size 256 next 274
# I0000 00:00:1773167092.449575   10867 bfc_allocator.cc:1105] InUse at 7a7acea74800 of size 256 next 275
# I0000 00:00:1773167092.449576   10867 bfc_allocator.cc:1105] InUse at 7a7acea74900 of size 165888 next 276
# I0000 00:00:1773167092.449577   10867 bfc_allocator.cc:1105] InUse at 7a7acea9d100 of size 165888 next 277
# I0000 00:00:1773167092.449578   10867 bfc_allocator.cc:1105] InUse at 7a7aceac5900 of size 512 next 278
# I0000 00:00:1773167092.449579   10867 bfc_allocator.cc:1105] InUse at 7a7aceac5b00 of size 512 next 279
# I0000 00:00:1773167092.449580   10867 bfc_allocator.cc:1105] InUse at 7a7aceac5d00 of size 331776 next 280
# I0000 00:00:1773167092.449581   10867 bfc_allocator.cc:1105] InUse at 7a7aceb16d00 of size 331776 next 281
# I0000 00:00:1773167092.449582   10867 bfc_allocator.cc:1105] InUse at 7a7aceb67d00 of size 512 next 282
# I0000 00:00:1773167092.449589   10867 bfc_allocator.cc:1105] InUse at 7a7aceb67f00 of size 512 next 283
# I0000 00:00:1773167092.449591   10867 bfc_allocator.cc:1105] InUse at 7a7aceb68100 of size 248832 next 284
# I0000 00:00:1773167092.449592   10867 bfc_allocator.cc:1105] InUse at 7a7aceba4d00 of size 248832 next 285
# I0000 00:00:1773167092.449593   10867 bfc_allocator.cc:1105] InUse at 7a7acebe1900 of size 256 next 286
# I0000 00:00:1773167092.449595   10867 bfc_allocator.cc:1105] InUse at 7a7acebe1a00 of size 256 next 287
# I0000 00:00:1773167092.449596   10867 bfc_allocator.cc:1105] InUse at 7a7acebe1b00 of size 82944 next 288
# I0000 00:00:1773167092.449598   10867 bfc_allocator.cc:1105] InUse at 7a7acebf5f00 of size 82944 next 289
# I0000 00:00:1773167092.449600   10867 bfc_allocator.cc:1105] InUse at 7a7acec0a300 of size 256 next 290
# I0000 00:00:1773167092.449601   10867 bfc_allocator.cc:1105] InUse at 7a7acec0a400 of size 256 next 291
# I0000 00:00:1773167092.449603   10867 bfc_allocator.cc:1105] InUse at 7a7acec0a500 of size 62208 next 292
# I0000 00:00:1773167092.449605   10867 bfc_allocator.cc:1105] InUse at 7a7acec19800 of size 62208 next 293
# I0000 00:00:1773167092.449606   10867 bfc_allocator.cc:1105] InUse at 7a7acec28b00 of size 256 next 294
# I0000 00:00:1773167092.449607   10867 bfc_allocator.cc:1105] InUse at 7a7acec28c00 of size 256 next 295
# I0000 00:00:1773167092.449625   10867 bfc_allocator.cc:1105] InUse at 7a7acec28d00 of size 20736 next 296
# I0000 00:00:1773167092.449626   10867 bfc_allocator.cc:1105] InUse at 7a7acec2de00 of size 20736 next 297
# I0000 00:00:1773167092.449627   10867 bfc_allocator.cc:1105] InUse at 7a7acec32f00 of size 256 next 298
# I0000 00:00:1773167092.449628   10867 bfc_allocator.cc:1105] InUse at 7a7acec33000 of size 256 next 299
# I0000 00:00:1773167092.449629   10867 bfc_allocator.cc:1105] InUse at 7a7acec33100 of size 256 next 300
# I0000 00:00:1773167092.449630   10867 bfc_allocator.cc:1105] InUse at 7a7acec33200 of size 256 next 301
# I0000 00:00:1773167092.449630   10867 bfc_allocator.cc:1105] InUse at 7a7acec33300 of size 256 next 302
# I0000 00:00:1773167092.449631   10867 bfc_allocator.cc:1105] InUse at 7a7acec33400 of size 256 next 303
# I0000 00:00:1773167092.449632   10867 bfc_allocator.cc:1105] Free  at 7a7acec33500 of size 1024 next 307
# I0000 00:00:1773167092.449656   10867 bfc_allocator.cc:1105] InUse at 7a7acec33900 of size 222086912 next 18446744073709551615
# I0000 00:00:1773167092.449657   10867 bfc_allocator.cc:1085] Next region of size 2097152
# I0000 00:00:1773167092.449659   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00000 of size 1280 next 1
# I0000 00:00:1773167092.449660   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00500 of size 256 next 2
# I0000 00:00:1773167092.449661   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00600 of size 256 next 3
# I0000 00:00:1773167092.449662   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00700 of size 256 next 4
# I0000 00:00:1773167092.449663   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00800 of size 256 next 5
# I0000 00:00:1773167092.449664   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00900 of size 256 next 7
# I0000 00:00:1773167092.449665   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00a00 of size 256 next 8
# I0000 00:00:1773167092.449666   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00b00 of size 256 next 6
# I0000 00:00:1773167092.449667   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00c00 of size 256 next 9
# I0000 00:00:1773167092.449668   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00d00 of size 256 next 14
# I0000 00:00:1773167092.449669   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00e00 of size 256 next 12
# I0000 00:00:1773167092.449670   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a00f00 of size 256 next 13
# I0000 00:00:1773167092.449671   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01000 of size 256 next 17
# I0000 00:00:1773167092.449672   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01100 of size 256 next 18
# I0000 00:00:1773167092.449672   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01200 of size 256 next 21
# I0000 00:00:1773167092.449673   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01300 of size 256 next 24
# I0000 00:00:1773167092.449674   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01400 of size 256 next 22
# I0000 00:00:1773167092.449675   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01500 of size 256 next 23
# I0000 00:00:1773167092.449676   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01600 of size 256 next 27
# I0000 00:00:1773167092.449677   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01700 of size 256 next 28
# I0000 00:00:1773167092.449678   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01800 of size 256 next 31
# I0000 00:00:1773167092.449697   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01900 of size 256 next 10
# I0000 00:00:1773167092.449698   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01a00 of size 256 next 41
# I0000 00:00:1773167092.449699   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01b00 of size 256 next 19
# I0000 00:00:1773167092.449699   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01c00 of size 256 next 38
# I0000 00:00:1773167092.449700   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01d00 of size 256 next 37
# I0000 00:00:1773167092.449701   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01e00 of size 256 next 32
# I0000 00:00:1773167092.449702   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a01f00 of size 256 next 154
# I0000 00:00:1773167092.449703   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02000 of size 256 next 157
# I0000 00:00:1773167092.449704   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02100 of size 256 next 159
# I0000 00:00:1773167092.449705   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02200 of size 256 next 153
# I0000 00:00:1773167092.449706   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02300 of size 256 next 36
# I0000 00:00:1773167092.449707   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02400 of size 256 next 40
# I0000 00:00:1773167092.449708   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02500 of size 256 next 33
# I0000 00:00:1773167092.449709   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02600 of size 256 next 42
# I0000 00:00:1773167092.449710   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02700 of size 256 next 45
# I0000 00:00:1773167092.449711   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02800 of size 256 next 44
# I0000 00:00:1773167092.449713   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02900 of size 256 next 46
# I0000 00:00:1773167092.449713   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02a00 of size 256 next 47
# I0000 00:00:1773167092.449714   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02b00 of size 256 next 63
# I0000 00:00:1773167092.449715   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02c00 of size 256 next 49
# I0000 00:00:1773167092.449716   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02d00 of size 256 next 50
# I0000 00:00:1773167092.449717   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02e00 of size 256 next 51
# I0000 00:00:1773167092.449718   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a02f00 of size 256 next 55
# I0000 00:00:1773167092.449719   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03000 of size 256 next 126
# I0000 00:00:1773167092.449720   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03100 of size 256 next 127
# I0000 00:00:1773167092.449721   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03200 of size 256 next 129
# I0000 00:00:1773167092.449722   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03300 of size 256 next 130
# I0000 00:00:1773167092.449723   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03400 of size 256 next 124
# I0000 00:00:1773167092.449724   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03500 of size 256 next 132
# I0000 00:00:1773167092.449725   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03600 of size 256 next 133
# I0000 00:00:1773167092.449726   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03700 of size 256 next 123
# I0000 00:00:1773167092.449726   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03800 of size 256 next 135
# I0000 00:00:1773167092.449728   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03900 of size 256 next 136
# I0000 00:00:1773167092.449728   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03a00 of size 256 next 128
# I0000 00:00:1773167092.449729   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03b00 of size 256 next 138
# I0000 00:00:1773167092.449730   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03c00 of size 256 next 139
# I0000 00:00:1773167092.449731   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03d00 of size 256 next 131
# I0000 00:00:1773167092.449732   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03e00 of size 256 next 141
# I0000 00:00:1773167092.449734   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a03f00 of size 256 next 142
# I0000 00:00:1773167092.449735   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04000 of size 256 next 134
# I0000 00:00:1773167092.449735   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04100 of size 256 next 144
# I0000 00:00:1773167092.449737   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04200 of size 256 next 145
# I0000 00:00:1773167092.449737   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04300 of size 256 next 137
# I0000 00:00:1773167092.449738   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04400 of size 256 next 147
# I0000 00:00:1773167092.449739   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04500 of size 256 next 148
# I0000 00:00:1773167092.449740   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04600 of size 256 next 140
# I0000 00:00:1773167092.449741   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04700 of size 256 next 143
# I0000 00:00:1773167092.449742   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04800 of size 256 next 122
# I0000 00:00:1773167092.449743   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04900 of size 256 next 56
# I0000 00:00:1773167092.449744   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04a00 of size 256 next 121
# I0000 00:00:1773167092.449745   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04b00 of size 256 next 65
# I0000 00:00:1773167092.449746   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04c00 of size 256 next 58
# I0000 00:00:1773167092.449747   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04d00 of size 256 next 117
# I0000 00:00:1773167092.449748   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a04e00 of size 1792 next 66
# I0000 00:00:1773167092.449749   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a05500 of size 14336 next 15
# I0000 00:00:1773167092.449751   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a08d00 of size 256 next 69
# I0000 00:00:1773167092.449752   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a08e00 of size 256 next 59
# I0000 00:00:1773167092.449753   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a08f00 of size 256 next 60
# I0000 00:00:1773167092.449754   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09000 of size 256 next 62
# I0000 00:00:1773167092.449755   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09100 of size 256 next 119
# I0000 00:00:1773167092.449756   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09200 of size 256 next 61
# I0000 00:00:1773167092.449757   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09300 of size 256 next 68
# I0000 00:00:1773167092.449758   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09400 of size 256 next 70
# I0000 00:00:1773167092.449758   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09500 of size 256 next 73
# I0000 00:00:1773167092.449759   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09600 of size 1792 next 74
# I0000 00:00:1773167092.449760   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a09d00 of size 1792 next 75
# I0000 00:00:1773167092.449762   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0a400 of size 256 next 76
# I0000 00:00:1773167092.449763   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0a500 of size 256 next 77
# I0000 00:00:1773167092.449764   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0a600 of size 12032 next 20
# I0000 00:00:1773167092.449764   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0d500 of size 256 next 162
# I0000 00:00:1773167092.449766   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0d600 of size 256 next 149
# I0000 00:00:1773167092.449766   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0d700 of size 256 next 164
# I0000 00:00:1773167092.449767   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0d800 of size 256 next 165
# I0000 00:00:1773167092.449768   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0d900 of size 256 next 166
# I0000 00:00:1773167092.449769   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0da00 of size 256 next 167
# I0000 00:00:1773167092.449770   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0db00 of size 256 next 53
# I0000 00:00:1773167092.449771   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0dc00 of size 256 next 208
# I0000 00:00:1773167092.449772   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0dd00 of size 1792 next 54
# I0000 00:00:1773167092.449773   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0e400 of size 1792 next 163
# I0000 00:00:1773167092.449774   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0eb00 of size 256 next 168
# I0000 00:00:1773167092.449775   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a0ec00 of size 10752 next 170
# I0000 00:00:1773167092.449777   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a11600 of size 11008 next 43
# I0000 00:00:1773167092.449778   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a14100 of size 9216 next 146
# I0000 00:00:1773167092.449778   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a16500 of size 9216 next 11
# I0000 00:00:1773167092.449779   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a18900 of size 256 next 169
# I0000 00:00:1773167092.449780   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a18a00 of size 256 next 171
# I0000 00:00:1773167092.449781   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a18b00 of size 256 next 152
# I0000 00:00:1773167092.449782   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a18c00 of size 256 next 173
# I0000 00:00:1773167092.449783   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a18d00 of size 256 next 151
# I0000 00:00:1773167092.449784   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a18e00 of size 256 next 176
# I0000 00:00:1773167092.449785   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a18f00 of size 256 next 180
# I0000 00:00:1773167092.449786   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19000 of size 256 next 179
# I0000 00:00:1773167092.449787   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19100 of size 256 next 182
# I0000 00:00:1773167092.449788   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19200 of size 256 next 183
# I0000 00:00:1773167092.449790   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19300 of size 256 next 186
# I0000 00:00:1773167092.449791   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19400 of size 256 next 187
# I0000 00:00:1773167092.449792   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19500 of size 256 next 191
# I0000 00:00:1773167092.449793   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19600 of size 256 next 190
# I0000 00:00:1773167092.449794   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19700 of size 256 next 195
# I0000 00:00:1773167092.449795   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19800 of size 256 next 194
# I0000 00:00:1773167092.449796   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a19900 of size 9216 next 198
# I0000 00:00:1773167092.449796   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1bd00 of size 256 next 201
# I0000 00:00:1773167092.449797   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1be00 of size 256 next 202
# I0000 00:00:1773167092.449798   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1bf00 of size 256 next 203
# I0000 00:00:1773167092.449799   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1c000 of size 256 next 204
# I0000 00:00:1773167092.449800   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1c100 of size 256 next 205
# I0000 00:00:1773167092.449801   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1c200 of size 256 next 206
# I0000 00:00:1773167092.449802   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1c300 of size 1792 next 207
# I0000 00:00:1773167092.449803   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a1ca00 of size 29440 next 26
# I0000 00:00:1773167092.449804   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a23d00 of size 36864 next 25
# I0000 00:00:1773167092.449805   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a2cd00 of size 36864 next 39
# I0000 00:00:1773167092.449805   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a35d00 of size 18432 next 16
# I0000 00:00:1773167092.449806   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a3a500 of size 36864 next 160
# I0000 00:00:1773167092.449807   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a43500 of size 55296 next 29
# I0000 00:00:1773167092.449808   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a50d00 of size 36864 next 57
# I0000 00:00:1773167092.449809   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a59d00 of size 73728 next 125
# I0000 00:00:1773167092.449810   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a6bd00 of size 184320 next 35
# I0000 00:00:1773167092.449811   10867 bfc_allocator.cc:1105] InUse at 7a7ba5a98d00 of size 147456 next 34
# I0000 00:00:1773167092.449812   10867 bfc_allocator.cc:1105] InUse at 7a7ba5abcd00 of size 36864 next 150
# I0000 00:00:1773167092.449813   10867 bfc_allocator.cc:1105] InUse at 7a7ba5ac5d00 of size 27648 next 161
# I0000 00:00:1773167092.449814   10867 bfc_allocator.cc:1105] InUse at 7a7ba5acc900 of size 18432 next 174
# I0000 00:00:1773167092.449815   10867 bfc_allocator.cc:1105] InUse at 7a7ba5ad1100 of size 73728 next 177
# I0000 00:00:1773167092.449816   10867 bfc_allocator.cc:1105] InUse at 7a7ba5ae3100 of size 211968 next 181
# I0000 00:00:1773167092.449817   10867 bfc_allocator.cc:1105] InUse at 7a7ba5b16d00 of size 110592 next 156
# I0000 00:00:1773167092.449818   10867 bfc_allocator.cc:1105] InUse at 7a7ba5b31d00 of size 147456 next 155
# I0000 00:00:1773167092.449819   10867 bfc_allocator.cc:1105] InUse at 7a7ba5b55d00 of size 110592 next 158
# I0000 00:00:1773167092.449820   10867 bfc_allocator.cc:1105] InUse at 7a7ba5b70d00 of size 147456 next 184
# I0000 00:00:1773167092.449821   10867 bfc_allocator.cc:1105] InUse at 7a7ba5b94d00 of size 147456 next 185
# I0000 00:00:1773167092.449822   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bb8d00 of size 36864 next 189
# I0000 00:00:1773167092.449823   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bc1d00 of size 36864 next 188
# I0000 00:00:1773167092.449824   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bcad00 of size 27648 next 193
# I0000 00:00:1773167092.449825   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bd1900 of size 27648 next 192
# I0000 00:00:1773167092.449827   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bd8500 of size 9216 next 196
# I0000 00:00:1773167092.449828   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bda900 of size 256 next 199
# I0000 00:00:1773167092.449829   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdaa00 of size 256 next 456
# I0000 00:00:1773167092.449830   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdab00 of size 256 next 457
# I0000 00:00:1773167092.449831   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdac00 of size 256 next 258
# I0000 00:00:1773167092.449832   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdad00 of size 256 next 458
# I0000 00:00:1773167092.449833   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdae00 of size 256 next 260
# I0000 00:00:1773167092.449834   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdaf00 of size 256 next 257
# I0000 00:00:1773167092.449835   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb000 of size 256 next 213
# I0000 00:00:1773167092.449835   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb100 of size 256 next 215
# I0000 00:00:1773167092.449837   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb200 of size 256 next 216
# I0000 00:00:1773167092.449838   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb300 of size 512 next 212
# I0000 00:00:1773167092.449839   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb500 of size 256 next 219
# I0000 00:00:1773167092.449840   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb600 of size 256 next 220
# I0000 00:00:1773167092.449841   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb700 of size 512 next 223
# I0000 00:00:1773167092.449842   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdb900 of size 256 next 224
# I0000 00:00:1773167092.449843   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdba00 of size 256 next 229
# I0000 00:00:1773167092.449844   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdbb00 of size 256 next 231
# I0000 00:00:1773167092.449845   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdbc00 of size 256 next 226
# I0000 00:00:1773167092.449846   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdbd00 of size 256 next 233
# I0000 00:00:1773167092.449847   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdbe00 of size 256 next 235
# I0000 00:00:1773167092.449848   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdbf00 of size 256 next 225
# I0000 00:00:1773167092.449849   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdc000 of size 256 next 238
# I0000 00:00:1773167092.449850   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdc100 of size 256 next 248
# I0000 00:00:1773167092.449851   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdc200 of size 256 next 239
# I0000 00:00:1773167092.449852   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdc300 of size 256 next 240
# I0000 00:00:1773167092.449853   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdc400 of size 256 next 197
# I0000 00:00:1773167092.449854   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdc500 of size 2816 next 178
# I0000 00:00:1773167092.449855   10867 bfc_allocator.cc:1105] Free  at 7a7ba5bdd000 of size 1536 next 246
# I0000 00:00:1773167092.449856   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdd600 of size 256 next 255
# I0000 00:00:1773167092.449857   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdd700 of size 256 next 250
# I0000 00:00:1773167092.449858   10867 bfc_allocator.cc:1105] Free  at 7a7ba5bdd800 of size 256 next 72
# I0000 00:00:1773167092.449859   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdd900 of size 2816 next 261
# I0000 00:00:1773167092.449860   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bde400 of size 2816 next 262
# I0000 00:00:1773167092.449861   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdef00 of size 256 next 263
# I0000 00:00:1773167092.449862   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdf000 of size 256 next 264
# I0000 00:00:1773167092.449864   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bdf100 of size 33024 next 172
# I0000 00:00:1773167092.449865   10867 bfc_allocator.cc:1105] InUse at 7a7ba5be7200 of size 20736 next 175
# I0000 00:00:1773167092.449867   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bec300 of size 20736 next 236
# I0000 00:00:1773167092.449869   10867 bfc_allocator.cc:1105] Free  at 7a7ba5bf1400 of size 26880 next 200
# I0000 00:00:1773167092.449871   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bf7d00 of size 9216 next 209
# I0000 00:00:1773167092.449872   10867 bfc_allocator.cc:1105] InUse at 7a7ba5bfa100 of size 24320 next 18446744073709551615
# I0000 00:00:1773167092.449874   10867 bfc_allocator.cc:1110]      Summary of in-use Chunks by size:
# I0000 00:00:1773167092.449876   10867 bfc_allocator.cc:1113] 187 Chunks of size 256 totalling 46.8KiB
# I0000 00:00:1773167092.449880   10867 bfc_allocator.cc:1113] 6 Chunks of size 512 totalling 3.0KiB
# I0000 00:00:1773167092.449883   10867 bfc_allocator.cc:1113] 1 Chunks of size 1280 totalling 1.2KiB
# I0000 00:00:1773167092.449885   10867 bfc_allocator.cc:1113] 6 Chunks of size 1792 totalling 10.5KiB
# I0000 00:00:1773167092.449887   10867 bfc_allocator.cc:1113] 3 Chunks of size 2816 totalling 8.2KiB
# I0000 00:00:1773167092.449888   10867 bfc_allocator.cc:1113] 8 Chunks of size 9216 totalling 72.0KiB
# I0000 00:00:1773167092.449889   10867 bfc_allocator.cc:1113] 1 Chunks of size 10752 totalling 10.5KiB
# I0000 00:00:1773167092.449891   10867 bfc_allocator.cc:1113] 1 Chunks of size 11008 totalling 10.8KiB
# I0000 00:00:1773167092.449892   10867 bfc_allocator.cc:1113] 1 Chunks of size 12032 totalling 11.8KiB
# I0000 00:00:1773167092.449893   10867 bfc_allocator.cc:1113] 1 Chunks of size 14336 totalling 14.0KiB
# I0000 00:00:1773167092.449894   10867 bfc_allocator.cc:1113] 4 Chunks of size 18432 totalling 72.0KiB
# I0000 00:00:1773167092.449896   10867 bfc_allocator.cc:1113] 5 Chunks of size 20736 totalling 101.2KiB
# I0000 00:00:1773167092.449897   10867 bfc_allocator.cc:1113] 1 Chunks of size 24320 totalling 23.8KiB
# I0000 00:00:1773167092.449898   10867 bfc_allocator.cc:1113] 5 Chunks of size 27648 totalling 135.0KiB
# I0000 00:00:1773167092.449900   10867 bfc_allocator.cc:1113] 1 Chunks of size 29440 totalling 28.8KiB
# I0000 00:00:1773167092.449901   10867 bfc_allocator.cc:1113] 1 Chunks of size 33024 totalling 32.2KiB
# I0000 00:00:1773167092.449902   10867 bfc_allocator.cc:1113] 12 Chunks of size 36864 totalling 432.0KiB
# I0000 00:00:1773167092.449904   10867 bfc_allocator.cc:1113] 3 Chunks of size 41472 totalling 121.5KiB
# I0000 00:00:1773167092.449905   10867 bfc_allocator.cc:1113] 1 Chunks of size 55296 totalling 54.0KiB
# I0000 00:00:1773167092.449906   10867 bfc_allocator.cc:1113] 2 Chunks of size 62208 totalling 121.5KiB
# I0000 00:00:1773167092.449907   10867 bfc_allocator.cc:1113] 5 Chunks of size 73728 totalling 360.0KiB
# I0000 00:00:1773167092.449909   10867 bfc_allocator.cc:1113] 6 Chunks of size 82944 totalling 486.0KiB
# I0000 00:00:1773167092.449910   10867 bfc_allocator.cc:1113] 1 Chunks of size 103680 totalling 101.2KiB
# I0000 00:00:1773167092.449912   10867 bfc_allocator.cc:1113] 4 Chunks of size 110592 totalling 432.0KiB
# I0000 00:00:1773167092.449913   10867 bfc_allocator.cc:1113] 7 Chunks of size 147456 totalling 1008.0KiB
# I0000 00:00:1773167092.449915   10867 bfc_allocator.cc:1113] 3 Chunks of size 165888 totalling 486.0KiB
# I0000 00:00:1773167092.449916   10867 bfc_allocator.cc:1113] 1 Chunks of size 184320 totalling 180.0KiB
# I0000 00:00:1773167092.449917   10867 bfc_allocator.cc:1113] 1 Chunks of size 211968 totalling 207.0KiB
# I0000 00:00:1773167092.449918   10867 bfc_allocator.cc:1113] 3 Chunks of size 248832 totalling 729.0KiB
# I0000 00:00:1773167092.449919   10867 bfc_allocator.cc:1113] 3 Chunks of size 331776 totalling 972.0KiB
# I0000 00:00:1773167092.449921   10867 bfc_allocator.cc:1113] 1 Chunks of size 1048576 totalling 1.00MiB
# I0000 00:00:1773167092.449922   10867 bfc_allocator.cc:1113] 1 Chunks of size 3436032 totalling 3.28MiB
# I0000 00:00:1773167092.449923   10867 bfc_allocator.cc:1113] 2 Chunks of size 12582912 totalling 24.00MiB
# I0000 00:00:1773167092.449925   10867 bfc_allocator.cc:1113] 1 Chunks of size 16777472 totalling 16.00MiB
# I0000 00:00:1773167092.449926   10867 bfc_allocator.cc:1113] 1 Chunks of size 17026048 totalling 16.24MiB
# I0000 00:00:1773167092.449928   10867 bfc_allocator.cc:1113] 1 Chunks of size 52428800 totalling 50.00MiB
# I0000 00:00:1773167092.449929   10867 bfc_allocator.cc:1113] 1 Chunks of size 54525952 totalling 52.00MiB
# I0000 00:00:1773167092.449931   10867 bfc_allocator.cc:1113] 1 Chunks of size 212860928 totalling 203.00MiB
# I0000 00:00:1773167092.449932   10867 bfc_allocator.cc:1113] 1 Chunks of size 222086912 totalling 211.80MiB
# I0000 00:00:1773167092.449933   10867 bfc_allocator.cc:1113] 1 Chunks of size 629145600 totalling 600.00MiB
# I0000 00:00:1773167092.449935   10867 bfc_allocator.cc:1117] Sum Total of in-use chunks: 1.16GiB
# I0000 00:00:1773167092.449936   10867 bfc_allocator.cc:1119] Total size in pool: 5.00GiB memory_limit_: 6.48GiB available size: 1.47GiB curr_region_allocation_bytes_: 8.00GiB
# I0000 00:00:1773167092.449938   10867 bfc_allocator.cc:1128] Stats:
# Limit:                         6.48GiB
# InUse:                         1.16GiB
# MaxInUse:                      4.90GiB
# NumAllocs:                       32176
# MaxAllocSize:                  4.00GiB
# Reserved:                           0B
# PeakReserved:                       0B
# LargestFreeBlock:                   0B
#
# W0000 00:00:1773167092.449944   10867 bfc_allocator.cc:513] ****___________________________________________________________________________*********************
# Epoch 1: val_iou_metric improved from None to 0.94976, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 101ms/step - dice_coefficient: 0.9339 - iou_metric: 0.9373 - loss: 0.2197 - val_dice_coefficient: 0.9595 - val_iou_metric: 0.9498 - val_loss: 0.1333 - learning_rate: 8.0000e-04
# Epoch 2/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - dice_coefficient: 0.9517 - iou_metric: 0.9417 - loss: 0.1689
# Epoch 2: val_iou_metric improved from 0.94976 to 0.95401, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - dice_coefficient: 0.9576 - iou_metric: 0.9475 - loss: 0.1433 - val_dice_coefficient: 0.9615 - val_iou_metric: 0.9540 - val_loss: 0.1186 - learning_rate: 8.0000e-04
# Epoch 3/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coefficient: 0.9566 - iou_metric: 0.9453 - loss: 0.1524
# Epoch 3: val_iou_metric did not improve from 0.95401
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - dice_coefficient: 0.9608 - iou_metric: 0.9495 - loss: 0.1327 - val_dice_coefficient: 0.9651 - val_iou_metric: 0.9523 - val_loss: 0.1108 - learning_rate: 8.0000e-04
# Epoch 4/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coefficient: 0.9611 - iou_metric: 0.9496 - loss: 0.1355
# Epoch 4: val_iou_metric improved from 0.95401 to 0.95530, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - dice_coefficient: 0.9655 - iou_metric: 0.9544 - loss: 0.1155 - val_dice_coefficient: 0.9655 - val_iou_metric: 0.9553 - val_loss: 0.1072 - learning_rate: 8.0000e-04
# Epoch 5/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coefficient: 0.9634 - iou_metric: 0.9530 - loss: 0.1284
# Epoch 5: val_iou_metric improved from 0.95530 to 0.96005, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - dice_coefficient: 0.9675 - iou_metric: 0.9573 - loss: 0.1094 - val_dice_coefficient: 0.9696 - val_iou_metric: 0.9601 - val_loss: 0.0990 - learning_rate: 8.0000e-04
# Epoch 6/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coefficient: 0.9661 - iou_metric: 0.9569 - loss: 0.1202
# Epoch 6: val_iou_metric improved from 0.96005 to 0.96258, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.9703 - iou_metric: 0.9613 - loss: 0.1005 - val_dice_coefficient: 0.9714 - val_iou_metric: 0.9626 - val_loss: 0.0949 - learning_rate: 8.0000e-04
# Epoch 7/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.9682 - iou_metric: 0.9598 - loss: 0.1153
# Epoch 7: val_iou_metric improved from 0.96258 to 0.96608, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.9719 - iou_metric: 0.9637 - loss: 0.0959 - val_dice_coefficient: 0.9748 - val_iou_metric: 0.9661 - val_loss: 0.0877 - learning_rate: 8.0000e-04
# Epoch 8/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.9704 - iou_metric: 0.9625 - loss: 0.1094
# Epoch 8: val_iou_metric improved from 0.96608 to 0.96789, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.9741 - iou_metric: 0.9665 - loss: 0.0891 - val_dice_coefficient: 0.9761 - val_iou_metric: 0.9679 - val_loss: 0.0839 - learning_rate: 8.0000e-04
# Epoch 9/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.9720 - iou_metric: 0.9648 - loss: 0.1048
# Epoch 9: val_iou_metric improved from 0.96789 to 0.96806, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.9757 - iou_metric: 0.9688 - loss: 0.0843 - val_dice_coefficient: 0.9771 - val_iou_metric: 0.9681 - val_loss: 0.0824 - learning_rate: 8.0000e-04
# Epoch 10/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.9737 - iou_metric: 0.9670 - loss: 0.0999
# Epoch 10: val_iou_metric improved from 0.96806 to 0.96916, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - dice_coefficient: 0.9771 - iou_metric: 0.9708 - loss: 0.0800 - val_dice_coefficient: 0.9782 - val_iou_metric: 0.9692 - val_loss: 0.0793 - learning_rate: 8.0000e-04
# Epoch 11/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.9738 - iou_metric: 0.9667 - loss: 0.0998
# Epoch 11: val_iou_metric improved from 0.96916 to 0.97345, saving model to models/runnable_road_baseline.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - dice_coefficient: 0.9773 - iou_metric: 0.9710 - loss: 0.0795 - val_dice_coefficient: 0.9812 - val_iou_metric: 0.9735 - val_loss: 0.0722 - learning_rate: 8.0000e-04
# Epoch 12/12
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coefficient: 0.9750 - iou_metric: 0.9686 - loss: 0.0963
# Epoch 12: val_iou_metric did not improve from 0.97345
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - dice_coefficient: 0.9787 - iou_metric: 0.9729 - loss: 0.0751 - val_dice_coefficient: 0.9820 - val_iou_metric: 0.9734 - val_loss: 0.0727 - learning_rate: 8.0000e-04
# Restoring model weights from the end of the best epoch: 11.
# Saved runnable-road model: models/runnable_road_baseline.keras

# %%
# Evaluate runnable-road segmentation
road_prob = road_model.predict(Xr_val, batch_size=BATCH_SIZE, verbose=0)
road_bin = (road_prob > 0.5).astype(np.float32)

road_inter = np.sum(Yr_val * road_bin, axis=(1, 2, 3))
road_union = np.sum(Yr_val, axis=(1, 2, 3)) + np.sum(road_bin, axis=(1, 2, 3)) - road_inter
road_iou = (road_inter + 1e-6) / (road_union + 1e-6)
print(f"Runnable-road IoU: {road_iou.mean():.4f} ± {road_iou.std():.4f}")

n_show = min(5, len(Xr_val))
idxs = np.linspace(0, len(Xr_val) - 1, n_show, dtype=int)
fig, axes = plt.subplots(n_show, 4, figsize=(14, 3 * n_show))
if n_show == 1:
    axes = np.expand_dims(axes, axis=0)

titles = ["Input", "Pseudo Runnable Road", "Pred Prob", "Pred Road (>0.5)"]
for c, t in enumerate(titles):
    axes[0, c].set_title(t, fontweight='bold')

for r, idx in enumerate(idxs):
    axes[r, 0].imshow(Xr_val[idx])
    axes[r, 1].imshow(Yr_val[idx, :, :, 0], cmap='gray', vmin=0, vmax=1)
    axes[r, 2].imshow(road_prob[idx, :, :, 0], cmap='viridis', vmin=0, vmax=1)
    axes[r, 3].imshow(road_bin[idx, :, :, 0], cmap='gray', vmin=0, vmax=1)
    axes[r, 0].set_ylabel(f"IoU={road_iou[idx]:.2f}", rotation=0, labelpad=35, fontsize=9, va='center')
    for c in range(4):
        axes[r, c].axis('off')

plt.suptitle("Runnable Road Segmentation — Validation Samples", fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Runnable-road IoU: 0.9732 ± 0.0523

# %% [markdown]
# ## 3. Runnable Road Refinement (v2)
#
# Reduce pseudo-label leakage by enforcing road texture constraints and curb-color exclusion before flood-fill.
#
# Refinements:
# - Low-gradient asphalt prior (Sobel magnitude threshold in lower ROI)
# - Curb exclusion (blue/white/red HSV masks)
# - Multi-seed flood fill fallback near bottom-center

# %%
# Build improved runnable-road pseudo-labels (v2)
ROAD_MODEL_V2_PATH = "models/runnable_road_baseline_v2.keras"
ROAD_EDGE_THRESH_V2 = 0.40

def build_curb_mask(img_rgb_u8):
    hsv = cv2.cvtColor(img_rgb_u8, cv2.COLOR_RGB2HSV)
    blue = cv2.inRange(hsv, (85, 60, 50), (135, 255, 255))
    red1 = cv2.inRange(hsv, (0, 70, 50), (10, 255, 255))
    red2 = cv2.inRange(hsv, (170, 70, 50), (180, 255, 255))
    white = cv2.inRange(hsv, (0, 0, 150), (180, 80, 255))
    curb = blue | red1 | red2 | white
    curb = cv2.morphologyEx(curb, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3)), iterations=1)
    return curb

def edge_to_runnable_road_v2(edge_prob, img_rgb_norm, edge_thresh=ROAD_EDGE_THRESH_V2):
    h, w = edge_prob.shape
    img_rgb_u8 = (img_rgb_norm * 255.0).astype(np.uint8)
    gray = cv2.cvtColor(img_rgb_u8, cv2.COLOR_RGB2GRAY)
    blur = cv2.GaussianBlur(gray, (5, 5), 0)

    gx = cv2.Sobel(blur, cv2.CV_32F, 1, 0, ksize=3)
    gy = cv2.Sobel(blur, cv2.CV_32F, 0, 1, ksize=3)
    grad = cv2.magnitude(gx, gy)

    roi = np.zeros((h, w), dtype=np.uint8)
    roi[int(h * 0.35):, :] = 255

    grad_roi = grad[roi > 0]
    thr = np.percentile(grad_roi, 68) if grad_roi.size > 0 else 18.0
    asphalt = (grad < thr).astype(np.uint8) * 255
    asphalt = cv2.morphologyEx(asphalt, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3)), iterations=1)

    edge_bin = (edge_prob > edge_thresh).astype(np.uint8) * 255
    edge_bin = cv2.dilate(edge_bin, cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3)), iterations=1)

    curb = build_curb_mask(img_rgb_u8)
    barrier = edge_bin | curb
    barrier = cv2.bitwise_and(barrier, roi)

    traversable = cv2.bitwise_and(asphalt, roi)
    traversable = cv2.bitwise_and(traversable, cv2.bitwise_not(barrier))

    ff = traversable.copy()
    ff_mask = np.zeros((h + 2, w + 2), dtype=np.uint8)
    seeds = [(w // 2, h - 2), (int(w * 0.45), h - 2), (int(w * 0.55), h - 2)]
    for sx, sy in seeds:
        if 0 <= sx < w and 0 <= sy < h and ff[sy, sx] > 0:
            cv2.floodFill(ff, ff_mask, seedPoint=(sx, sy), newVal=128)

    road = (ff == 128).astype(np.uint8)
    road = cv2.morphologyEx(road, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3)), iterations=1)
    road = cv2.morphologyEx(road, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7, 7)), iterations=1)

    # Remove tiny islands
    nlab, lab, stats, _ = cv2.connectedComponentsWithStats(road, connectivity=8)
    cleaned = np.zeros_like(road)
    min_area = int(0.003 * h * w)
    for j in range(1, nlab):
        if stats[j, cv2.CC_STAT_AREA] >= min_area:
            cleaned[lab == j] = 1

    return cleaned.astype(np.float32)

if 'edge_prob_all' not in globals() or edge_prob_all is None or len(edge_prob_all) != len(X):
    edge_prob_all = edge_model.predict(X, batch_size=BATCH_SIZE, verbose=0)

Y_road_v2 = np.zeros((len(X), IMG_H, IMG_W, 1), dtype=np.float32)
for i in range(len(X)):
    Y_road_v2[i, :, :, 0] = edge_to_runnable_road_v2(edge_prob_all[i, :, :, 0], X[i])

Xr2_train, Xr2_val, Yr2_train, Yr2_val = train_test_split(
    X, Y_road_v2, test_size=0.20, random_state=42
 )

print(f"Road v2 pseudo-labels: total {len(X)} | train {len(Xr2_train)} | val {len(Xr2_val)}")
print(f"Road v1 coverage (train/val): {Yr_train.mean()*100:.2f}% / {Yr_val.mean()*100:.2f}%")
print(f"Road v2 coverage (train/val): {Yr2_train.mean()*100:.2f}% / {Yr2_val.mean()*100:.2f}%")
# Out:
# Road v2 pseudo-labels: total 2000 | train 1600 | val 400
# Road v1 coverage (train/val): 94.31% / 94.56%
# Road v2 coverage (train/val): 20.41% / 20.72%

# %%
# Train runnable-road segmentation on v2 pseudo-labels
def dice_loss(y_true, y_pred):
    return 1.0 - dice_coefficient(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return bce + 0.5 * dice_loss(y_true, y_pred)

tf.keras.backend.clear_session()
road_model_v2 = build_road_baseline()
road_model_v2.compile(
    optimizer=keras.optimizers.Adam(6e-4),
    loss=bce_dice_loss,
    metrics=[dice_coefficient, iou_metric],
)
road_model_v2.summary()

road_callbacks_v2 = [
    ModelCheckpoint(ROAD_MODEL_V2_PATH, monitor='val_iou_metric', mode='max', save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_iou_metric', mode='max', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1),
]

road_history_v2 = road_model_v2.fit(
    Xr2_train, Yr2_train,
    validation_data=(Xr2_val, Yr2_val),
    epochs=14,
    batch_size=BATCH_SIZE,
    callbacks=road_callbacks_v2,
    verbose=1,
 )

road_model_v2 = tf.keras.models.load_model(
    ROAD_MODEL_V2_PATH,
    custom_objects={
        'dice_coefficient': dice_coefficient,
        'iou_metric': iou_metric,
        'dice_loss': dice_loss,
        'bce_dice_loss': bce_dice_loss,
    },
)
print(f"Saved runnable-road v2 model: {ROAD_MODEL_V2_PATH}")
# Out:
# Model: "runnable_road_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 256,  │        672 │ input_layer[0][0] │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 256,  │      5,208 │ conv2d[0][0]      │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 128,   │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 128,   │     10,416 │ max_pooling2d[0]… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 128,   │     20,784 │ conv2d_2[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 64,    │     41,568 │ max_pooling2d_1[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 64,    │     83,040 │ conv2d_4[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 128,   │          0 │ conv2d_5[0][0]    │
# │ (UpSampling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 128,   │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 144)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 128,   │     62,256 │ concatenate[0][0] │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 128,   │     20,784 │ conv2d_6[0][0]    │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 256,  │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 256,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 72)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 256,  │     15,576 │ concatenate_1[0]… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 256,  │      5,208 │ conv2d_8[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 256,  │         25 │ conv2d_9[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 265,537 (1.01 MB)
#  Trainable params: 265,537 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - dice_coefficient: 0.2784 - iou_metric: 0.0219 - loss: 0.8524
# Epoch 1: val_iou_metric improved from None to 0.37362, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - dice_coefficient: 0.3262 - iou_metric: 0.0952 - loss: 0.7739 - val_dice_coefficient: 0.4244 - val_iou_metric: 0.3736 - val_loss: 0.7553 - learning_rate: 6.0000e-04
# Epoch 2/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - dice_coefficient: 0.4541 - iou_metric: 0.3640 - loss: 0.6443
# Epoch 2: val_iou_metric improved from 0.37362 to 0.44970, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - dice_coefficient: 0.4714 - iou_metric: 0.3750 - loss: 0.6267 - val_dice_coefficient: 0.5162 - val_iou_metric: 0.4497 - val_loss: 0.5809 - learning_rate: 6.0000e-04
# Epoch 3/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coefficient: 0.5014 - iou_metric: 0.4237 - loss: 0.5973
# Epoch 3: val_iou_metric improved from 0.44970 to 0.47711, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - dice_coefficient: 0.5150 - iou_metric: 0.4322 - loss: 0.5821 - val_dice_coefficient: 0.5433 - val_iou_metric: 0.4771 - val_loss: 0.5767 - learning_rate: 6.0000e-04
# Epoch 4/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - dice_coefficient: 0.5562 - iou_metric: 0.4740 - loss: 0.5349
# Epoch 4: val_iou_metric improved from 0.47711 to 0.50966, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.5666 - iou_metric: 0.4818 - loss: 0.5249 - val_dice_coefficient: 0.6061 - val_iou_metric: 0.5097 - val_loss: 0.5444 - learning_rate: 6.0000e-04
# Epoch 5/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.5787 - iou_metric: 0.4943 - loss: 0.5123
# Epoch 5: val_iou_metric improved from 0.50966 to 0.52420, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.5834 - iou_metric: 0.5013 - loss: 0.5078 - val_dice_coefficient: 0.6195 - val_iou_metric: 0.5242 - val_loss: 0.5119 - learning_rate: 6.0000e-04
# Epoch 6/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.6144 - iou_metric: 0.5349 - loss: 0.4728
# Epoch 6: val_iou_metric improved from 0.52420 to 0.54220, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.6151 - iou_metric: 0.5371 - loss: 0.4732 - val_dice_coefficient: 0.6298 - val_iou_metric: 0.5422 - val_loss: 0.4807 - learning_rate: 6.0000e-04
# Epoch 7/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.6269 - iou_metric: 0.5471 - loss: 0.4571
# Epoch 7: val_iou_metric improved from 0.54220 to 0.55421, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.6300 - iou_metric: 0.5519 - loss: 0.4554 - val_dice_coefficient: 0.6426 - val_iou_metric: 0.5542 - val_loss: 0.4594 - learning_rate: 6.0000e-04
# Epoch 8/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coefficient: 0.6337 - iou_metric: 0.5551 - loss: 0.4493
# Epoch 8: val_iou_metric did not improve from 0.55421
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - dice_coefficient: 0.6371 - iou_metric: 0.5597 - loss: 0.4477 - val_dice_coefficient: 0.6505 - val_iou_metric: 0.5542 - val_loss: 0.4674 - learning_rate: 6.0000e-04
# Epoch 9/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coefficient: 0.6494 - iou_metric: 0.5685 - loss: 0.4316
# Epoch 9: val_iou_metric improved from 0.55421 to 0.56914, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - dice_coefficient: 0.6516 - iou_metric: 0.5731 - loss: 0.4302 - val_dice_coefficient: 0.6602 - val_iou_metric: 0.5691 - val_loss: 0.4395 - learning_rate: 6.0000e-04
# Epoch 10/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coefficient: 0.6584 - iou_metric: 0.5780 - loss: 0.4214
# Epoch 10: val_iou_metric improved from 0.56914 to 0.58341, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - dice_coefficient: 0.6612 - iou_metric: 0.5824 - loss: 0.4192 - val_dice_coefficient: 0.6735 - val_iou_metric: 0.5834 - val_loss: 0.4246 - learning_rate: 6.0000e-04
# Epoch 11/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coefficient: 0.6711 - iou_metric: 0.5924 - loss: 0.4066
# Epoch 11: val_iou_metric did not improve from 0.58341
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - dice_coefficient: 0.6723 - iou_metric: 0.5931 - loss: 0.4067 - val_dice_coefficient: 0.6714 - val_iou_metric: 0.5763 - val_loss: 0.4267 - learning_rate: 6.0000e-04
# Epoch 12/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coefficient: 0.6798 - iou_metric: 0.5995 - loss: 0.3962
# Epoch 12: val_iou_metric improved from 0.58341 to 0.58666, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - dice_coefficient: 0.6840 - iou_metric: 0.6057 - loss: 0.3928 - val_dice_coefficient: 0.6784 - val_iou_metric: 0.5867 - val_loss: 0.4192 - learning_rate: 6.0000e-04
# Epoch 13/14
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coefficient: 0.6864 - iou_metric: 0.6078 - loss: 0.3884
# Epoch 13: val_iou_metric improved from 0.58666 to 0.59031, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - dice_coefficient: 0.6902 - iou_metric: 0.6124 - loss: 0.3852 - val_dice_coefficient: 0.6886 - val_iou_metric: 0.5903 - val_loss: 0.4154 - learning_rate: 6.0000e-04
# Epoch 14/14
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - dice_coefficient: 0.6983 - iou_metric: 0.6196 - loss: 0.3761
# Epoch 14: val_iou_metric improved from 0.59031 to 0.62088, saving model to models/runnable_road_baseline_v2.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - dice_coefficient: 0.6991 - iou_metric: 0.6217 - loss: 0.3752 - val_dice_coefficient: 0.7072 - val_iou_metric: 0.6209 - val_loss: 0.3816 - learning_rate: 6.0000e-04
# Restoring model weights from the end of the best epoch: 14.
# Saved runnable-road v2 model: models/runnable_road_baseline_v2.keras

# %%
# Evaluate v2 and compare against v1 pseudo-label quality
road_prob_v2 = road_model_v2.predict(Xr2_val, batch_size=BATCH_SIZE, verbose=0)
road_bin_v2 = (road_prob_v2 > 0.5).astype(np.float32)

inter_v2 = np.sum(Yr2_val * road_bin_v2, axis=(1, 2, 3))
union_v2 = np.sum(Yr2_val, axis=(1, 2, 3)) + np.sum(road_bin_v2, axis=(1, 2, 3)) - inter_v2
iou_v2 = (inter_v2 + 1e-6) / (union_v2 + 1e-6)
print(f"Runnable-road v2 IoU: {iou_v2.mean():.4f} ± {iou_v2.std():.4f}")

n_show = min(5, len(Xr2_val))
idxs = np.linspace(0, len(Xr2_val) - 1, n_show, dtype=int)
fig, axes = plt.subplots(n_show, 5, figsize=(17, 3 * n_show))
if n_show == 1:
    axes = np.expand_dims(axes, axis=0)

titles = ["Input", "Pseudo Road v2", "Pred Prob v2", "Pred Road v2", "Overlay"]
for c, t in enumerate(titles):
    axes[0, c].set_title(t, fontweight='bold')

for r, idx in enumerate(idxs):
    img = Xr2_val[idx]
    gt = Yr2_val[idx, :, :, 0]
    pr = road_prob_v2[idx, :, :, 0]
    pb = road_bin_v2[idx, :, :, 0]

    overlay = img.copy()
    green = np.zeros_like(img)
    green[..., 1] = pb
    overlay = np.clip(0.65 * overlay + 0.35 * green, 0, 1)

    axes[r, 0].imshow(img)
    axes[r, 1].imshow(gt, cmap='gray', vmin=0, vmax=1)
    axes[r, 2].imshow(pr, cmap='viridis', vmin=0, vmax=1)
    axes[r, 3].imshow(pb, cmap='gray', vmin=0, vmax=1)
    axes[r, 4].imshow(overlay)
    axes[r, 0].set_ylabel(f"IoU={iou_v2[idx]:.2f}", rotation=0, labelpad=35, fontsize=9, va='center')
    for c in range(5):
        axes[r, c].axis('off')

plt.suptitle("Runnable Road Refinement v2 — Validation Samples", fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Runnable-road v2 IoU: 0.5940 ± 0.2946
